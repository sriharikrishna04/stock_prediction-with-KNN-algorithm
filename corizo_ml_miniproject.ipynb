# %% [markdown]
# <a href="https://colab.research.google.com/github/sriharikrishna04/stock_prediction-with-KNN-algorithm/blob/main/corizo_ml_miniproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the requirements
import pandas as pd
import yfinance as yf
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# %%
#getting the dataset
data=yf.Ticker("^GSPC")
data=data.history(period="max")
display(data)
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-09-09 00:00:00-04:00  5442.069824  5484.200195  5434.490234  5471.049805
# 2024-09-10 00:00:00-04:00  5490.509766  5497.910156  5441.720215  5495.520020
# 2024-09-11 00:00:00-04:00  5496.419922  5560.410156  5406.959961  5554.129883
# 2024-09-12 00:00:00-04:00  5557.479980  5600.709961  5535.500000  5595.759766
# 2024-09-13 00:00:00-04:00  5603.339844  5636.270020  5601.649902  5626.020020
#
# ...

# %%
#preprocessing
#removing the unwanted attributes
del data['Dividends']
del data['Stock Splits']
del data['Volume']
data
# Out:
#                                   Open         High          Low        Close
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-09-09 00:00:00-04:00  5442.069824  5484.200195  5434.490234  5471.049805
# 2024-09-10 00:00:00-04:00  5490.509766  5497.910156  5441.720215  5495.520020
# 2024-09-11 00:00:00-04:00  5496.419922  5560.410156  5406.959961  5554.129883
# 2024-09-12 00:00:00-04:00  5557.479980  5600.709961  5535.500000  5595.759766
# 2024-09-13 00:00:00-04:00  5603.339844  5636.270020  5601.649902  5626.020020
#
# [24292 rows x 4 columns]

# %%
data['tomorrow']=data['Close'].shift(-1) #creating the tomorrow attribute to predict the stock
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-09-09 00:00:00-04:00  5442.069824  5484.200195  5434.490234  5471.049805
# 2024-09-10 00:00:00-04:00  5490.509766  5497.910156  5441.720215  5495.520020
# 2024-09-11 00:00:00-04:00  5496.419922  5560.410156  5406.959961  5554.129883
# 2024-09-12 00:00:00-04:00  5557.479980  5600.709961  5535.500000  5595.759766
# 2024-09-13 00:00:00-04:00  5603.339844  5636.270020  5601.649902  5626.020020
#
# ...

# %%
data['target']=(data['tomorrow']>data['Close']).astype(int) # creating the target attribute to predict the future sales
data
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-09-09 00:00:00-04:00  5442.069824  5484.200195  5434.490234  5471.049805
# 2024-09-10 00:00:00-04:00  5490.509766  5497.910156  5441.720215  5495.520020
# 2024-09-11 00:00:00-04:00  5496.419922  5560.410156  5406.959961  5554.129883
# 2024-09-12 00:00:00-04:00  5557.479980  5600.709961  5535.500000  5595.759766
# 2024-09-13 00:00:00-04:00  5603.339844  5636.270020  5601.649902  5626.020020
#
# ...

# %%
data = data.dropna() #to remove the None value
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42) #train and test


#  Standardize the data
scaler = StandardScaler()
xtrain_scaled = scaler.fit_transform(xtrain)
xtest_scaled = scaler.transform(xtest)

#  Initialize the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # you can change the number of neighbors (k)

#  Train the model
knn.fit(xtrain_scaled, ytrain)

#  Make predictions
ypred = knn.predict(xtest_scaled)
print(ypred)
# Out:
# [0 1 0 ... 1 1 0]

# %%
#  Standardize the data
scaler = StandardScaler()
xtrain_scaled = scaler.fit_transform(xtrain)
xtest_scaled = scaler.transform(xtest)

# Initialize the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # you can change the number of neighbors (k)

#  Train the model
knn.fit(xtrain_scaled, ytrain)

#  Make predictions
ypred = knn.predict(xtest_scaled)

# Evaluate the model's performance
accuracy = accuracy_score(ytest, ypred)
report = classification_report(ytest, ypred)

print(f"Accuracy: {accuracy * 100:.2f}%")
print("Classification Report:\n", report)
# Out:
# Accuracy: 86.56%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86      2306
#            1       0.86      0.89      0.87      2553
#
#     accuracy                           0.87      4859
#    macro avg       0.87      0.86      0.87      4859
# weighted avg       0.87      0.87      0.87      4859

# %%
warnings.filterwarnings('ignore')

external_test_data = np.array([[4400, 4450, 4380, 4425,4490]]) #external input
external_test_scaled = scaler.transform(external_test_data) #standardize the input
external_prediction = knn.predict(external_test_scaled) #apply KNN

if external_prediction[0] == 1:
    print("Prediction: The market will go up tomorrow.")
else:
    print("Prediction: The market will go down tomorrow.")
# Out:
# Prediction: The market will go up tomorrow.
